# %%
print(1)
# Out:
# 1

# %%
print('we are going to do sth')
# Out:
# we are going to do sth

# %%
print('we\'re going to do sth')
# Out:
# we're going to do sth

# %%
print('hello'+'world')
# Out:
# helloworld

# %%
print('#'*9)
# Out:
# #########

# %%
print(str(9)+'s')
# Out:
# 9s

# %%
print(int('1')+2)
# Out:
# 3

# %%
print(float('1.2')+2)
# Out:
# 3.2

# %%
print('11\t12\n21\t22')
# Out:
# 11	12
# 21	22\

# %%
print(r'11\t12\n21\t22')
# Out:
# 11\t12\n21\t22

# %%
print('\\\\\n\\\\\\t\\\\')
# Out:
# \\
# \\\t\\

# %%
dir('print')
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
help('print')
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
for func in dir('print'):
    help('print'+'.'+func)
# Out:
# No Python documentation found for 'print.__add__'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
#
# Help on class builtin_function_or_method in print:
#
# print.__class__ = class builtin_function_or_method(object)
#  |  Methods defined here:
#  |
#  |  __call__(self, /, *args, **kwargs)
#  |      Call self as a function.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __reduce__(...)
#  |      helper for pickle
#  |
#  |  __repr__(self, /)
# ...
